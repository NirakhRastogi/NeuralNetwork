# %% [markdown]
# <a href="https://colab.research.google.com/github/NirakhRastogi/NeuralNetwork/blob/main/HousingPriceBeginner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
print(np.__version__)
# Out:
# 2.3.0
# 1.18.5

# %%
from google.colab import files
uploaded = files.upload()
csv_housefile = next(iter(uploadded))
print('Uploaded files "{name}" with length "{length}" bhyes '.format(name=csv_housefile, length = len(uploaded[csv_housefile])))
# Out:
#      <input type="file" id="files-4f8f7713-318a-43f3-a7f0-9410b8410b9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f8f7713-318a-43f3-a7f0-9410b8410b9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HousePricing.csv to HousePricing (2).csv
# Uploaded files "HousePricing.csv" with length "20138" bhyes

# %%
import pandas as pd
df_housing = pd.read_csv(csv_housefile)

# %%
df_housing.head(5)
# Out:
#    Order        PID  MS SubClass  ... Sale Type  Sale Condition  SalePrice
# 0      1  526301100           20  ...       WD           Normal     215000
# 1     13  527166040           60  ...       WD           Normal     180400
# 2     38  528112020           20  ...       WD           Normal     306000
# 3     56  528240070           60  ...       WD           Normal     216500
# 4     59  528292020           60  ...       WD           Normal     222500
#
# [5 rows x 82 columns]
